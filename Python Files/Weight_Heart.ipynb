# %% [markdown]
# # Weight_Log

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Weight_LogInfo_merged = pd.read_csv('/content/drive/MyDrive/weightLogInfo_merged.csv')

# %%
Weight_LogInfo_merged.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
#Check null valuea
#Weight_LogInfo_merged.isnull().sum()

# %%
Weight_LogInfo_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     object
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   Fat             2 non-null      float64
#  5   BMI             67 non-null     float64
#  6   IsManualReport  67 non-null     bool
#  7   LogId           67 non-null     int64
# dtypes: bool(1), float64(4), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
Weight_LogInfo_merged.describe()
# Out:
#                  Id    WeightKg  WeightPounds       Fat        BMI  \
# count  6.700000e+01   67.000000     67.000000   2.00000  67.000000
# mean   7.009282e+09   72.035821    158.811801  23.50000  25.185224
# std    1.950322e+09   13.923206     30.695415   2.12132   3.066963
# min    1.503960e+09   52.599998    115.963147  22.00000  21.450001
# 25%    6.962181e+09   61.400002    135.363832  22.75000  23.959999
# 50%    6.962181e+09   62.500000    137.788914  23.50000  24.389999
# 75%    8.877689e+09   85.049999    187.503152  24.25000  25.559999
# max    8.877689e+09  133.500000    294.317120  25.00000  47.540001
#
#               LogId
# count  6.700000e+01
# mean   1.461772e+12
# std    7.829948e+08
# min    1.460444e+12
# 25%    1.461079e+12
# 50%    1.461802e+12
# 75%    1.462375e+12
# max    1.463098e+12

# %%
Weight_LogInfo_merged.duplicated().sum()
# Out:
# 0

# %%
Weight_LogInfo_merged['Date'] = pd.to_datetime(Weight_LogInfo_merged['Date'])
Weight_LogInfo_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     datetime64[ns]
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   Fat             2 non-null      float64
#  5   BMI             67 non-null     float64
#  6   IsManualReport  67 non-null     bool
#  7   LogId           67 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(2)
# memory usage: 3.9 KB
# <ipython-input-115-f2e85525dac4>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Weight_LogInfo_merged['Date'] = pd.to_datetime(Weight_LogInfo_merged['Date'])

# %%
#Code Extract Time
Weight_LogInfo_merged["Date"].dt.time
# Out:
# 0     23:59:59
# 1     23:59:59
# 2     01:08:52
# 3     23:59:59
# 4     23:59:59
#         ...
# 62    06:43:35
# 63    07:35:53
# 64    06:39:44
# 65    06:51:47
# 66    06:42:53
# Name: Date, Length: 67, dtype: object

# %%
Weight_LogInfo_merged['Hour'] = Weight_LogInfo_merged['Date'].dt.time
Weight_LogInfo_merged.head()
# Out:
#            Id                Date    WeightKg  WeightPounds   Fat        BMI  \
# 0  1503960366 2016-05-02 23:59:59   52.599998    115.963147  22.0  22.650000
# 1  1503960366 2016-05-03 23:59:59   52.599998    115.963147   NaN  22.650000
# 2  1927972279 2016-04-13 01:08:52  133.500000    294.317120   NaN  47.540001
# 3  2873212765 2016-04-21 23:59:59   56.700001    125.002104   NaN  21.450001
# 4  2873212765 2016-05-12 23:59:59   57.299999    126.324875   NaN  21.690001
#
#    IsManualReport          LogId      Hour
# 0            True  1462233599000  23:59:59
# 1            True  1462319999000  23:59:59
# 2           False  1460509732000  01:08:52
# 3            True  1461283199000  23:59:59
# 4            True  1463097599000  23:59:59

# %%
# Convert Date and format
Weight_LogInfo_merged['Dates'] = pd.to_datetime(Weight_LogInfo_merged['Date'])
Weight_LogInfo_merged['Dates'] = pd.to_datetime(Weight_LogInfo_merged['Date']).dt.strftime('%m/%d/%Y')

# %%
Weight_LogInfo_merged.head()
# Out:
#            Id                Date    WeightKg  WeightPounds   Fat        BMI  \
# 0  1503960366 2016-05-02 23:59:59   52.599998    115.963147  22.0  22.650000
# 1  1503960366 2016-05-03 23:59:59   52.599998    115.963147   NaN  22.650000
# 2  1927972279 2016-04-13 01:08:52  133.500000    294.317120   NaN  47.540001
# 3  2873212765 2016-04-21 23:59:59   56.700001    125.002104   NaN  21.450001
# 4  2873212765 2016-05-12 23:59:59   57.299999    126.324875   NaN  21.690001
#
#    IsManualReport          LogId      Hour       Dates
# 0            True  1462233599000  23:59:59  05/02/2016
# 1            True  1462319999000  23:59:59  05/03/2016
# 2           False  1460509732000  01:08:52  04/13/2016
# 3            True  1461283199000  23:59:59  04/21/2016
# 4            True  1463097599000  23:59:59  05/12/2016

# %%
del Weight_LogInfo_merged['Dates']

# %%
Weight_LogInfo_merged.head()
# Out:
#            Id                Date    WeightKg  WeightPounds   Fat        BMI  \
# 0  1503960366 2016-05-02 23:59:59   52.599998    115.963147  22.0  22.650000
# 1  1503960366 2016-05-03 23:59:59   52.599998    115.963147   NaN  22.650000
# 2  1927972279 2016-04-13 01:08:52  133.500000    294.317120   NaN  47.540001
# 3  2873212765 2016-04-21 23:59:59   56.700001    125.002104   NaN  21.450001
# 4  2873212765 2016-05-12 23:59:59   57.299999    126.324875   NaN  21.690001
#
#    IsManualReport          LogId      Hour
# 0            True  1462233599000  23:59:59
# 1            True  1462319999000  23:59:59
# 2           False  1460509732000  01:08:52
# 3            True  1461283199000  23:59:59
# 4            True  1463097599000  23:59:59

# %% [markdown]
# Heart Rate

# %%
Heart_Rate_second = pd.read_csv('/content/drive/MyDrive/heartrate_seconds_merged.csv')

# %%
Heart_Rate_second.head()
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101

# %%
Heart_Rate_second.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    object
#  2   Value   int64
# dtypes: int64(2), object(1)
# memory usage: 56.8+ MB

# %%
Heart_Rate_second["Time"] = pd.to_datetime(Heart_Rate_second["Time"])
Heart_Rate_second.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    datetime64[ns]
#  2   Value   int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 56.8 MB

# %%
#Code Extract  Time
Heart_Rate_second["Time"].dt.time
# Out:
# 0          07:21:00
# 1          07:21:05
# 2          07:21:10
# 3          07:21:20
# 4          07:21:25
#              ...
# 2483653    14:43:53
# 2483654    14:43:58
# 2483655    14:44:03
# 2483656    14:44:18
# 2483657    14:44:28
# Name: Time, Length: 2483658, dtype: object

# %%
Heart_Rate_second["Hours"] = Heart_Rate_second["Time"].dt.time
Heart_Rate_second.head()
# Out:
#            Id                Time  Value     Hours
# 0  2022484408 2016-04-12 07:21:00     97  07:21:00
# 1  2022484408 2016-04-12 07:21:05    102  07:21:05
# 2  2022484408 2016-04-12 07:21:10    105  07:21:10
# 3  2022484408 2016-04-12 07:21:20    103  07:21:20
# 4  2022484408 2016-04-12 07:21:25    101  07:21:25

# %%
# Convert ActivityMinute and format
Heart_Rate_second['Date'] = pd.to_datetime(Heart_Rate_second['Time'])
Heart_Rate_second['Date'] = pd.to_datetime(Heart_Rate_second['Time']).dt.strftime('%m/%d/%Y')

# %%
Heart_Rate_second.head()
# Out:
#            Id                Time  Value     Hours        Date
# 0  2022484408 2016-04-12 07:21:00     97  07:21:00  04/12/2016
# 1  2022484408 2016-04-12 07:21:05    102  07:21:05  04/12/2016
# 2  2022484408 2016-04-12 07:21:10    105  07:21:10  04/12/2016
# 3  2022484408 2016-04-12 07:21:20    103  07:21:20  04/12/2016
# 4  2022484408 2016-04-12 07:21:25    101  07:21:25  04/12/2016

# %%
del Heart_Rate_second['Time']

# %%
Heart_Rate_second.head()
# Out:
#            Id  Value     Hours        Date
# 0  2022484408     97  07:21:00  04/12/2016
# 1  2022484408    102  07:21:05  04/12/2016
# 2  2022484408    105  07:21:10  04/12/2016
# 3  2022484408    103  07:21:20  04/12/2016
# 4  2022484408    101  07:21:25  04/12/2016

# %%
#Check null valuea
Heart_Rate_second.isnull().sum()
# Out:
# Id       0
# Value    0
# Hours    0
# Date     0
# dtype: int64

# %%
#Save the merged dataset to a new CSV file
Weight_LogInfo_merged.to_csv('Weights_LogInfo_merged.csv', index=False)
Heart_Rate_second.to_csv('Heart_Rates_second.csv', index=False)
